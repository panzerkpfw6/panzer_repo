# %%
#!/usr/bin/env python
import os,sys
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import glob
import re
import math

# %%
# !pwd
# !unzip ./grid_perf/emerald_rapids.zip -d ./grid_perf/
# !unzip ./grid_perf/Shaheen3_genoa_results.zip -d ./grid_perf/

# %%
#######################################
#### data export from files
# list_of_folders=['./scaling/7773X','./scaling/7763',
# './scaling/Flamingo',
# './scaling/Kanary','./scaling/Shaheen']

# SH3 folder
list_of_folders=['./grid_perf/Shaheen3_genoa_results']

# # emerald rapids folder
# list_of_folders=['./grid_perf/emerald_rapids']
sim_info=[]
times=[]
giga_points=[]
giga_flops = []
point_updates = []
flops=[]
method=[]
grids=[]
filenames=[]
cores=[]
import glob
####################### Parse files and aggregate them into the dataframe #######################
for data_folder in list_of_folders:
    print(os.getcwd())
    # filenames_list=os.listdir(data_folder)
    filenames_list=glob.glob(os.path.join(data_folder,'*--*') )
    #### filter filenames list
    for index,filename in enumerate(filenames_list):
        print(index,filename)
        with open(os.path.join(filename),'r') as file:
            previous_line=''
            if '2023-12-17-13-41-42--0--388022' in filename:
                ss=1
            if '2023-12-01-20-34-09--4--723' in filename:
                ss=1
            for line in file:
                if '.out' in line:
                    info_line=line
                    lines=info_line.split(';')
                    for tmp_line in lines:
                        if '.out' in tmp_line:
                            launch_line=tmp_line
                    parsed_commands=launch_line.split(' ')
                    for parsed_command in parsed_commands:
                        if '.out' in parsed_command:
                            command_launch_binary=parsed_command
                            code_type=command_launch_binary.split('/')[-2]
                            # print(code_type)
                            if code_type=='SB': tmp_method='sb'
                            if code_type=='SB_abc': tmp_method='sb_abc'
                            if code_type=='TB': tmp_method='tb'
                            if code_type=='TB_abc': tmp_method='tb_abc'
                            if code_type=='SB_order2': tmp_method='sb_order2'
                            if code_type=='SB_order2_abc': tmp_method='sb_order2_abc'
                            if code_type=='TB_order2': tmp_method='tb_order2'
                            if code_type=='TB_order2_abc': tmp_method='tb_order2_abc'
                if '********** START SB KERNEL ***********' in line:
                    start_new_simulation_read=1                    
                    tmp_time=math.nan
                    tmp_giga_points=math.nan
                    tmp_giga_flops=math.nan
                    tmp_point_updates=math.nan
                    tmp_flops=math.nan
                    tmp_grid=math.nan
                elif '**** START TB KERNEL FIRST ORDER *****' in line:
                    start_new_simulation_read=1
                    tmp_time=math.nan
                    tmp_giga_points=math.nan
                    tmp_giga_flops=math.nan
                    tmp_point_updates=math.nan
                    tmp_flops=math.nan
                    tmp_grid=math.nan
                elif 'GRID' in line and issubclass(type(tmp_grid), str)==False:
                    if np.isnan(tmp_grid):
                        tmp_grid=(line.split('GRID')[-1])
                        tmp_grid=(tmp_grid.split('\n')[0])
                        tmp_grid=tmp_grid.strip()
                elif 'ELAPSED TIME (s)' in line and np.isnan(tmp_time):
                    tmp_time=(float(line.split()[-1]))
                elif 'GIGA POINT / s' in line and np.isnan(tmp_giga_points):
                    tmp_giga_points=(float(line.split()[-1]))
                elif 'GIGA FLOP / s' in line and np.isnan(tmp_giga_flops):
                    tmp_giga_flops=(float(line.split()[-1]))
                elif '# POINT UPDATES' in line and np.isnan(tmp_point_updates):
                    tmp_point_updates=(float(line.split()[-1]))
                elif 'FLOP' in line and np.isnan(tmp_flops):
                    tmp_flops=(float(line.split()[-1]))   
                elif 'R-' in line and 'R-TB1noABC' in line:
                    tmp_method='tb'
                elif 'R-' in line and 'R-TB1withABC' in line:
                    tmp_method='tb_abc'
                elif '# THREADS' in line:
                    tmp_ncores=(float(line.split()[-1]))
                elif ('********** END SB KERNEL *************' in line) or ('********** END TB KERNEL *************' in line):
                    cores.append(tmp_ncores)
                    filenames.append(filename)
                    sim_info.append(info_line)
                    times.append(tmp_time)
                    giga_points.append(tmp_giga_points)
                    giga_flops.append(tmp_giga_flops)
                    point_updates.append(tmp_point_updates)
                    flops.append(tmp_flops)
                    method.append( tmp_method)
                    grids.append(tmp_grid)
                    # code_type.append(tmp.split('_')[1])
                    # num_th.append( float (tmp.split('_')[2]) )
                    sss=1
                previous_line=line
        # print(filename)

# Créer un DataFrame à partir des listes
data = pd.DataFrame({
    'filenames':filenames,
    'method':method,
    'grids':grids,
    'giga_point_s':giga_points,
    'cores':cores,
    'sim_info':sim_info,
    'times':times,
    'giga_flop_s': giga_flops,
    'point_updates': point_updates,
    'Flops': flops,
    })
print(data.columns)
######################  find available grids
print(data['grids'].unique())
print(data['method'].unique())
# grids_=['512 x 512 x 512','1024 x 1024 x 512','2048 x 2048 x 512','2048 x 2048 x 1024','2048 x 2048 x 2048']
grids_=['512 x 512 x 512','1024 x 1024 x 512','2048 x 2048 x 512']
print('results will be plotted for grids=',grids_)
data_list_1st_grid=[]
data_list_2nd_grid=[]
metric='giga_point_s'
print(data['cores'].unique())
print(data['method'].unique())
print(data.columns)

####################### Create summary for dataframe  #######################
data_summary=data.copy()
data_summary=data_summary.drop(columns=['giga_flop_s','point_updates','Flops','sim_info','times'])
data_summary.to_excel(os.path.join("data_summary_whole_data.xlsx"))
####################### Parse dataframe and create list with values to plot #######################
ee=data[data['method']=='sb_abc']
# data_grid_sb=data_summary.iloc[0,:]
data_tmp = pd.DataFrame({
    'filenames':[],
    'method':[],
    'grids':[],
    'giga_point_s':[],
    'cores':[]})
thread_list=[96,192]

for grid_ in grids_:
    data_grid=data_summary[data_summary['grids']==grid_]
    data_grid=data_grid[data_grid['cores']==192]
    # data_grid=data_grid[data_grid['cores']==128]

    # choose code type
    data_grid_sb=data_grid[data_grid['method']=='sb']
    data_grid_sb_abc=data_grid[data_grid['method']=='sb_abc']
    data_grid_tb=data_grid[data_grid['method']=='tb']
    data_grid_tb_abc=data_grid[data_grid['method']=='tb_abc']

    data_grid_sb_order2=data_grid[data_grid['method']=='sb_order2']
    data_grid_sb_order2_abc=data_grid[data_grid['method']=='sb_order2_abc']
    data_grid_tb_order2=data_grid[data_grid['method']=='tb_order2']
    data_grid_tb_order2_abc=data_grid[data_grid['method']=='tb_order2_abc']

    # sort results by performance
    data_grid_sb=data_grid_sb.sort_values(by=['giga_point_s'],ascending=False)
    data_grid_sb_abc=data_grid_sb_abc.sort_values(by=['giga_point_s'],ascending=False)
    data_grid_tb=data_grid_tb.sort_values(by=['giga_point_s'],ascending=False)
    data_grid_tb_abc=data_grid_tb_abc.sort_values(by=['giga_point_s'],ascending=False)

    data_grid_sb_order2=data_grid_sb_order2.sort_values(by=['giga_point_s'],ascending=False)
    data_grid_sb_order2_abc=data_grid_sb_order2_abc.sort_values(by=['giga_point_s'],ascending=False)
    data_grid_tb_order2=data_grid_tb_order2.sort_values(by=['giga_point_s'],ascending=False)
    data_grid_tb_order2_abc=data_grid_tb_order2_abc.sort_values(by=['giga_point_s'],ascending=False)
    ######################### copy to excel
    # data_grid_sb_=data_grid_sb.iloc[0,:]
    # data_grid_sb_abc_=data_grid_sb_abc.iloc[0,:]
    # data_grid_tb_=data_grid_tb.iloc[0,:]
    # data_grid_tb_abc_=data_grid_tb_abc.iloc[0,:]
    # data_tmp = data_tmp.append(data_grid_sb_)
    # data_tmp = data_tmp.append(data_grid_sb_abc_)
    # data_tmp = data_tmp.append(data_grid_tb_)
    # data_tmp = data_tmp.append(data_grid_tb_abc_)
    
    # data_grid_sb_order2_=data_grid_sb_order2.iloc[0,:]
    # data_grid_sb_order2_abc_=data_grid_sb_order2_abc.iloc[0,:]
    # data_grid_tb_order2_=data_grid_tb_order2.iloc[0,:]
    # data_grid_tb_order2_abc_=data_grid_tb_order2_abc.iloc[0,:]
    # data_tmp = data_tmp.append(data_grid_sb_order2_)
    # data_tmp = data_tmp.append(data_grid_sb_order2_abc_)
    # data_tmp = data_tmp.append(data_grid_tb_order2_)
    # data_tmp = data_tmp.append(data_grid_tb_order2_abc_)
    #########################
    ##### record 1st order results
    if len(data_grid_sb[metric].values)!=0:
        sb_val=data_grid_sb[metric].values[0]
    else:
        sb_val=math.nan

    if len(data_grid_sb_abc[metric].values)!=0:
        sb_abc_val=data_grid_sb_abc[metric].values[0]
    else:
        sb_abc_val=math.nan

    if len(data_grid_tb[metric].values)!=0:
        tb_val=data_grid_tb[metric].values[0]
    else:
        tb_val=math.nan

    if len(data_grid_tb_abc[metric].values)!=0:
        tb_abc_val=data_grid_tb_abc[metric].values[0]
    else:
        tb_abc_val=math.nan
    print([grid_,sb_val,tb_val,sb_abc_val,tb_abc_val])
    data_list_1st_grid.append([grid_,sb_val,tb_val,sb_abc_val,tb_abc_val])
    ##### record 2nd order results
    if len(data_grid_sb_order2[metric].values)!=0:
        sb_val=data_grid_sb_order2[metric].values[0]
    else:
        sb_val=math.nan

    if len(data_grid_sb_order2_abc[metric].values)!=0:
        sb_abc_val=data_grid_sb_order2_abc[metric].values[0]
    else:
        sb_abc_val=math.nan

    if len(data_grid_tb_order2[metric].values)!=0:
        tb_val=data_grid_tb_order2[metric].values[0]
    else:
        tb_val=math.nan

    if len(data_grid_tb_order2_abc[metric].values)!=0:
        tb_abc_val=data_grid_tb_order2_abc[metric].values[0]
    else:
        tb_abc_val=math.nan
    data_list_2nd_grid.append([grid_,sb_val,tb_val,sb_abc_val,tb_abc_val])
    #########################
data_tmp.to_excel(os.path.join("data_summary2.xlsx"))
ss=1
# Out:
# /Users/pavelplotnitskii/Dropbox/Apps/Overleaf/2024_pasc_seismic/figures/pavel
# 0 ./grid_perf/Shaheen3_genoa_results/2024-01-07-08-42-11--2887--581170
# 1 ./grid_perf/Shaheen3_genoa_results/2024-01-09-09-06-47--967--589297
# 2 ./grid_perf/Shaheen3_genoa_results/2024-01-04-10-57-15--3970--558782
# 3 ./grid_perf/Shaheen3_genoa_results/2024-01-07-08-42-11--3645--581950
# 4 ./grid_perf/Shaheen3_genoa_results/2024-01-09-09-06-47--2419--590843
# 5 ./grid_perf/Shaheen3_genoa_results/2024-01-09-09-06-47--2521--590945
# 6 ./grid_perf/Shaheen3_genoa_results/2024-01-07-08-42-11--2378--580598
# 7 ./grid_perf/Shaheen3_genoa_results/2024-01-07-08-42-11--813--579025
# 8 ./grid_perf/Shaheen3_genoa_results/2024-01-04-10-57-15--2075--556654
# 9 ./grid_perf/Shaheen3_genoa_results/2023-12-17-13-41-42--1332--389983
# 10 ./grid_perf/Shaheen3_genoa_results/2024-01-07-08-42-11--1797--580011
# 11 ./grid_perf/Shaheen3_genoa_results/2024-01-04-10-57-15--4732--571004
# 12 ./grid_perf/Shaheen3_genoa_results/2024-01-04-10-57-15--1969--556521
# 13 ./grid_perf/Shaheen3_genoa_results/2023-12-17-13-41-42--1440--390283
# 14 ./grid_perf/Shaheen3_genoa_results/2024-01-09-09-06-47--3576--592005
# 15 ./grid_perf/Shaheen3_genoa_results/2023-12-17-13-41-42--293--503185
# 16 ./grid_perf/Shaheen3_genoa_results/2023-12-17-13-41-42--246--503382
# 17 ./grid_perf/Shaheen3_genoa_results/2024-01-04-10-57-15--2667--557444
# 18 ./grid_perf/Shaheen3_genoa_results/2024-01-04-10-57-15--4799--571073
# 19 ./grid_perf/Shaheen3_genoa_results/2024-01-04-10-57-15--3785--558597
# 20 ./grid_perf/Shaheen3_genoa_results/2024-01-04-10-57-15--2372--557088
# 21 ./grid_perf/Shaheen3_genoa_results/2024-01-07-08-42-11--2076--580290
# 22 ./grid_perf/Shaheen3_genoa_results/2024-01-04-10-57-15--176--554082
# 23 ./grid_perf/Shaheen3_genoa_results/2024-01-07-08-42-11--4951--583325
# 24 ./grid_perf/Shaheen3_genoa_results/2024-01-04-10-57-15--3199--558007
# 25 ./grid_perf/Shaheen3_genoa_results/2024-01-09-09-06-47--2570--590996
# 26 ./grid_perf/Shaheen3_genoa_results/2024-01-07-08-42-11--217--578429
# 27 ./grid_perf/Shaheen3_genoa_results/2024-01-07-08-42-11--28--578148
# 28 ./grid_perf/Shaheen3_genoa_results/2023-12-17-13-41-42--678--503514
# 29 ./grid_perf/Shaheen3_genoa_results/2023-12-17-13-41-42--979--389562
# 30 ./grid_perf/Shaheen3_genoa_results/2024-01-09-09-06-47--592--584336
# 31 ./grid_perf/Shaheen3_genoa_results/2024-01-09-09-06-47--272--584016
# 32 ./grid_perf/Shaheen3_genoa_results/2024-01-04-10-57-15--3522--558332
# 33 ./grid_perf/Shaheen3_genoa_results/2024-01-09-09-06-47--410--584154
# 34 ./grid_perf/Shaheen3_genoa_results/2024-01-04-10-57-15--4429--570693
# 35 ./grid_perf/Shaheen3_genoa_results/2024-01-04-10-57-15--2556--557329
# 36 ./grid_perf/Shaheen3_genoa_results/2024-01-09-09-06-47--5053--593507
# 37 ./grid_perf/Shaheen3_genoa_results/2024-01-07-08-42-11--236--578448
# 38 ./grid_perf/Shaheen3_genoa_results/2024-01-07-08-42-11--4970--583344
# 39 ./grid_perf/Shaheen3_genoa_results/2024-01-09-09-06-47--1118--589472
# 40 ./grid_perf/Shaheen3_genoa_results/2024-01-09-09-06-47--1669--590076
# 41 ./grid_perf/Shaheen3_genoa_results/2024-01-07-08-42-11--128--578340
# 42 ./grid_perf/Shaheen3_genoa_results/2024-01-04-10-57-15--3858--558670
# 43 ./grid_perf/Shaheen3_genoa_results/2024-01-04-10-57-15--1609--556130
# 44 ./grid_perf/Shaheen3_genoa_results/2024-01-04-10-57-15--4667--570934
# 45 ./grid_perf/Shaheen3_genoa_results/2024-01-09-09-06-47--214--583958
# 46 ./grid_perf/Shaheen3_genoa_results/2024-01-07-08-42-11--588--578800
# 47 ./grid_perf/Shaheen3_genoa_results/2024-01-07-08-42-11--2765--581034
# 48 ./grid_perf/Shaheen3_genoa_results/2024-01-09-09-06-47--3394--591822
# 49 ./grid_perf/Shaheen3_genoa_results/2024-01-07-08-42-11--2505--580739
# 50 ./grid_perf/Shaheen3_genoa_results/2023-12-17-13-41-42--768--389175
# 51 ./grid_perf/Shaheen3_genoa_results/2024-01-04-10-57-15--1908--556446
# 52 ./grid_perf/Shaheen3_genoa_results/2024-01-09-09-06-47--2500--590924
# 53 ./grid_perf/Shaheen3_genoa_results/2024-01-07-08-42-11--832--579044
# 54 ./grid_perf/Shaheen3_genoa_results/2024-01-09-09-06-47--3094--591520
# 55 ./grid_perf/Shaheen3_genoa_results/2024-01-04-10-57-15--654--555081
# 56 ./grid_perf/Shaheen3_genoa_results/2024-01-09-09-06-47--230--583974
# 57 ./grid_perf/Shaheen3_genoa_results/2024-01-04-10-57-15--723--555150
# 58 ./grid_perf/Shaheen3_genoa_results/2024-01-04-10-57-15--818--555258
# 59 ./grid_perf/Shaheen3_genoa_results/2024-01-07-08-42-11--19--578129
# 60 ./grid_perf/Shaheen3_genoa_results/2024-01-09-09-06-47--434--584178
# 61 ./grid_perf/Shaheen3_genoa_results/2024-01-04-10-57-15--2198--556793
# 62 ./grid_perf/Shaheen3_genoa_results/2023-12-17-13-41-42--367--503044
# 63 ./grid_perf/Shaheen3_genoa_results/2024-01-07-08-42-11--1885--580099
# 64 ./grid_perf/Shaheen3_genoa_results/2024-01-07-08-42-11--1323--579536
# 65 ./grid_perf/Shaheen3_genoa_results/2024-01-09-09-06-47--2972--591398
# 66 ./grid_perf/Shaheen3_genoa_results/2024-01-09-09-06-47--3443--591872
# 67 ./grid_perf/Shaheen3_genoa_results/2023-12-17-13-41-42--214--503032
# 68 ./grid_perf/Shaheen3_genoa_results/2024-01-07-08-42-11--3429--581733
# 69 ./grid_perf/Shaheen3_genoa_results/2024-01-07-08-42-11--763--578975
# 70 ./grid_perf/Shaheen3_genoa_results/2024-01-04-10-57-15--1050--555507
# 71 ./grid_perf/Shaheen3_genoa_results/2023-12-17-13-41-42--672--503215
# 72 ./grid_perf/Shaheen3_genoa_results/2024-01-09-09-06-47--3135--591561
# 73 ./grid_perf/Shaheen3_genoa_results/2023-12-17-13-41-42--1499--392561
# 74 ./grid_perf/Shaheen3_genoa_results/2024-01-07-08-42-11--1585--579799
# 75 ./grid_perf/Shaheen3_genoa_results/2024-01-04-10-57-15--466--554890
# 76 ./grid_perf/Shaheen3_genoa_results/2024-01-09-09-06-47--24--583768
# 77 ./grid_perf/Shaheen3_genoa_results/2024-01-07-08-42-11--5012--583387
# 78 ./grid_perf/Shaheen3_genoa_results/2024-01-09-09-06-47--3517--591946
# 79 ./grid_perf/Shaheen3_genoa_results/2024-01-07-08-42-11--3774--582080
# 80 ./grid_perf/Shaheen3_genoa_results/2024-01-04-10-57-15--2681--557460
# 81 ./grid_perf/Shaheen3_genoa_results/2024-01-09-09-06-47--3977--592416
# 82 ./grid_perf/Shaheen3_genoa_results/2024-01-04-10-57-15--3375--558184
# 83 ./grid_perf/Shaheen3_genoa_results/2024-01-09-09-06-47--4760--593213
# 84 ./grid_perf/Shaheen3_genoa_results/2024-01-09-09-06-47--1181--589535
# 85 ./grid_perf/Shaheen3_genoa_results/2024-01-07-08-42-11--3046--581344
# 86 ./grid_perf/Shaheen3_genoa_results/2024-01-07-08-42-11--4825--583197
# 87 ./grid_perf/Shaheen3_genoa_results/2024-01-09-09-06-47--3808--592242
# 88 ./grid_perf/Shaheen3_genoa_results/2023-12-17-13-41-42--1251--389901
# 89 ./grid_perf/Shaheen3_genoa_results/2024-01-04-10-57-15--4869--571147
# 90 ./grid_perf/Shaheen3_genoa_results/2023-12-17-13-41-42--1284--389934
# 91 ./grid_perf/Shaheen3_genoa_results/2024-01-04-10-57-15--1378--555896
# 92 ./grid_perf/Shaheen3_genoa_results/2024-01-07-08-42-11--747--578959
# 93 ./grid_perf/Shaheen3_genoa_results/2024-01-07-08-42-11--3883--582189
# 94 ./grid_perf/Shaheen3_genoa_results/2024-01-07-08-42-11--457--578669
# 95 ./grid_perf/Shaheen3_genoa_results/2024-01-07-08-42-11--2769--581040
# 96 ./grid_perf/Shaheen3_genoa_results/2024-01-09-09-06-47--2745--591171
# 97 ./grid_perf/Shaheen3_genoa_results/2024-01-09-09-06-47--1986--590403
# 98 ./grid_perf/Shaheen3_genoa_results/2024-01-09-09-06-47--4936--593390
# 99 ./grid_perf/Shaheen3_genoa_results/2024-01-09-09-06-47--3636--592066
# 100 ./grid_perf/Shaheen3_genoa_results/2024-01-09-09-06-47--1623--590027
# 101 ./grid_perf/Shaheen3_genoa_results/2024-01-04-10-57-15--756--555190
# 102 ./grid_perf/Shaheen3_genoa_results/2024-01-04-10-57-15--977--555433
# 103 ./grid_perf/Shaheen3_genoa_results/2024-01-09-09-06-47--1098--589452
# 104 ./grid_perf/Shaheen3_genoa_results/2024-01-04-10-57-15--1410--555929
# 105 ./grid_perf/Shaheen3_genoa_results/2024-01-04-10-57-15--270--554692
# 106 ./grid_perf/Shaheen3_genoa_results/2024-01-09-09-06-47--3271--591697
# 107 ./grid_perf/Shaheen3_genoa_results/2024-01-04-10-57-15--3457--558267
# 108 ./grid_perf/Shaheen3_genoa_results/2024-01-07-08-42-11--2240--580455
# 109 ./grid_perf/Shaheen3_genoa_results/2024-01-04-10-57-15--2546--557316
# 110 ./grid_perf/Shaheen3_genoa_results/2024-01-09-09-06-47--2263--590687
# 111 ./grid_perf/Shaheen3_genoa_results/2024-01-09-09-06-47--4794--593247
# 112 ./grid_perf/Shaheen3_genoa_results/2024-01-07-08-42-11--4986--583360
# 113 ./grid_perf/Shaheen3_genoa_results/2024-01-07-08-42-11--43--578178
# 114 ./grid_perf/Shaheen3_genoa_results/2024-01-09-09-06-47--796--589125
# 115 ./grid_perf/Shaheen3_genoa_results/2024-01-04-10-57-15--4990--578061
# 116 ./grid_perf/Shaheen3_genoa_results/2024-01-04-10-57-15--4846--571122
# 117 ./grid_perf/Shaheen3_genoa_results/2024-01-09-09-06-47--2480--590904
# 118 ./grid_perf/Shaheen3_genoa_results/2024-01-09-09-06-47--749--589078
# 119 ./grid_perf/Shaheen3_genoa_results/2024-01-09-09-06-47--1003--589333
# 120 ./grid_perf/Shaheen3_genoa_results/2024-01-04-10-57-15--4099--560114
# 121 ./grid_perf/Shaheen3_genoa_results/2024-01-09-09-06-47--1230--589584
# 122 ./grid_perf/Shaheen3_genoa_results/2024-01-09-09-06-47--1369--589723
# 123 ./grid_perf/Shaheen3_genoa_results/2024-01-09-09-06-47--5130--593585
# 124 ./grid_perf/Shaheen3_genoa_results/2023-12-17-13-41-42--1170--389802
# 125 ./grid_perf/Shaheen3_genoa_results/2024-01-09-09-06-47--2216--590640
# 126 ./grid_perf/Shaheen3_genoa_results/2024-01-04-10-57-15--1087--555545
# 127 ./grid_perf/Shaheen3_genoa_results/2024-01-09-09-06-47--1840--590257
# 128 ./grid_perf/Shaheen3_genoa_results/2024-01-04-10-57-15--2939--557740
# 129 ./grid_perf/Shaheen3_genoa_results/2024-01-04-10-57-15--5110--578281
# 130 ./grid_perf/Shaheen3_genoa_results/2024-01-04-10-57-15--1610--556131
# 131 ./grid_perf/Shaheen3_genoa_results/2024-01-04-10-57-15--333--554757
# 132 ./grid_perf/Shaheen3_genoa_results/2024-01-09-09-06-47--1670--590077
# 133 ./grid_perf/Shaheen3_genoa_results/2024-01-04-10-57-15--3496--558306
# 134 ./grid_perf/Shaheen3_genoa_results/2024-01-04-10-57-15--3919--558731
# 135 ./grid_perf/Shaheen3_genoa_results/2024-01-09-09-06-47--332--584076
# 136 ./grid_perf/Shaheen3_genoa_results/2024-01-09-09-06-47--407--584151
# 137 ./grid_perf/Shaheen3_genoa_results/2024-01-04-10-57-15--3463--558273
# 138 ./grid_perf/Shaheen3_genoa_results/2024-01-07-08-42-11--3703--582008
# 139 ./grid_perf/Shaheen3_genoa_results/2024-01-07-08-42-11--4967--583341
# 140 ./grid_perf/Shaheen3_genoa_results/2024-01-09-09-06-47--2838--591264
# 141 ./grid_perf/Shaheen3_genoa_results/2024-01-07-08-42-11--1000--579213
# 142 ./grid_perf/Shaheen3_genoa_results/2024-01-04-10-57-15--5082--578225
# 143 ./grid_perf/Shaheen3_genoa_results/2024-01-04-10-57-15--2341--557055
# 144 ./grid_perf/Shaheen3_genoa_results/2024-01-07-08-42-11--2666--580926
# 145 ./grid_perf/Shaheen3_genoa_results/2024-01-07-08-42-11--2762--581031
# 146 ./grid_perf/Shaheen3_genoa_results/2024-01-07-08-42-11--3720--582026
# 147 ./grid_perf/Shaheen3_genoa_results/2024-01-09-09-06-47--2618--591044
# 148 ./grid_perf/Shaheen3_genoa_results/2024-01-09-09-06-47--4567--593020
# 149 ./grid_perf/Shaheen3_genoa_results/2024-01-09-09-06-47--2441--590865
# 150 ./grid_perf/Shaheen3_genoa_results/2024-01-04-10-57-15--2646--557422
# 151 ./grid_perf/Shaheen3_genoa_results/2024-01-04-10-57-15--847--555288
# 152 ./grid_perf/Shaheen3_genoa_results/2024-01-09-09-06-47--227--583971
# 153 ./grid_perf/Shaheen3_genoa_results/2024-01-09-09-06-47--4586--593039
# 154 ./grid_perf/Shaheen3_genoa_results/2023-12-17-13-41-42--1364--390044
# 155 ./grid_perf/Shaheen3_genoa_results/2024-01-09-09-06-47--3454--591883
# 156 ./grid_perf/Shaheen3_genoa_results/2023-12-17-13-41-42--1014--389623
# 157 ./grid_perf/Shaheen3_genoa_results/2024-01-07-08-42-11--87--578266
# 158 ./grid_perf/Shaheen3_genoa_results/2023-12-17-13-41-42--1142--389767
# 159 ./grid_perf/Shaheen3_genoa_results/2024-01-07-08-42-11--1674--579888
# 160 ./grid_perf/Shaheen3_genoa_results/2024-01-09-09-06-47--1394--589749
# 161 ./grid_perf/Shaheen3_genoa_results/2024-01-09-09-06-47--3523--591952
# 162 ./grid_perf/Shaheen3_genoa_results/2024-01-04-10-57-15--2756--557543
# 163 ./grid_perf/Shaheen3_genoa_results/2024-01-09-09-06-47--4029--592471
# 164 ./grid_perf/Shaheen3_genoa_results/2024-01-09-09-06-47--3914--592350
# 165 ./grid_perf/Shaheen3_genoa_results/2024-01-04-10-57-15--643--555070
# 166 ./grid_perf/Shaheen3_genoa_results/2024-01-04-10-57-15--3281--558089
# 167 ./grid_perf/Shaheen3_genoa_results/2023-12-17-13-41-42--1335--389986
# 168 ./grid_perf/Shaheen3_genoa_results/2024-01-04-10-57-15--2608--557382
# 169 ./grid_perf/Shaheen3_genoa_results/2024-01-07-08-42-11--496--578708
# 170 ./grid_perf/Shaheen3_genoa_results/2024-01-04-10-57-15--532--554957
# 171 ./grid_perf/Shaheen3_genoa_results/2024-01-04-10-57-15--2827--557625
# 172 ./grid_perf/Shaheen3_genoa_results/2024-01-07-08-42-11--3267--581570
# 173 ./grid_perf/Shaheen3_genoa_results/2024-01-07-08-42-11--1183--579396
# 174 ./grid_perf/Shaheen3_genoa_results/2024-01-09-09-06-47--3571--592000
# 175 ./grid_perf/Shaheen3_genoa_results/2024-01-09-09-06-47--4045--592488
# 176 ./grid_perf/Shaheen3_genoa_results/2024-01-09-09-06-47--1058--589412
# 177 ./grid_perf/Shaheen3_genoa_results/2024-01-09-09-06-47--1160--589514
# 178 ./grid_perf/Shaheen3_genoa_results/2024-01-09-09-06-47--122--583866
# 179 ./grid_perf/Shaheen3_genoa_results/2024-01-07-08-42-11--4811--583183
# 180 ./grid_perf/Shaheen3_genoa_results/2024-01-09-09-06-47--1417--589773
# 181 ./grid_perf/Shaheen3_genoa_results/2024-01-09-09-06-47--660--588989
# 182 ./grid_perf/Shaheen3_genoa_results/2024-01-09-09-06-47--2567--590993
# 183 ./grid_perf/Shaheen3_genoa_results/2024-01-07-08-42-11--356--578568
# 184 ./grid_perf/Shaheen3_genoa_results/2024-01-07-08-42-11--4946--583320
# 185 ./grid_perf/Shaheen3_genoa_results/2024-01-09-09-06-47--4754--593207
# 186 ./grid_perf/Shaheen3_genoa_results/2024-01-04-10-57-15--4501--570766
# 187 ./grid_perf/Shaheen3_genoa_results/2024-01-04-10-57-15--312--554736
# 188 ./grid_perf/Shaheen3_genoa_results/2024-01-09-09-06-47--3945--592383
# 189 ./grid_perf/Shaheen3_genoa_results/2024-01-04-10-57-15--3938--558750
# 190 ./grid_perf/Shaheen3_genoa_results/2024-01-04-10-57-15--4888--571166
# 191 ./grid_perf/Shaheen3_genoa_results/2023-12-17-13-41-42--1265--389915
# 192 ./grid_perf/Shaheen3_genoa_results/2024-01-04-10-57-15--4759--571033
# 193 ./grid_perf/Shaheen3_genoa_results/2024-01-07-08-42-11--1978--580192
# 194 ./grid_perf/Shaheen3_genoa_results/2024-01-04-10-57-15--4851--571127
# 195 ./grid_perf/Shaheen3_genoa_results/2024-01-04-10-57-15--4653--570920
# 196 ./grid_perf/Shaheen3_genoa_results/2024-01-04-10-57-15--4989--578060
# 197 ./grid_perf/Shaheen3_genoa_results/2024-01-09-09-06-47--2625--591051
# 198 ./grid_perf/Shaheen3_genoa_results/2024-01-07-08-42-11--537--578749
# 199 ./grid_perf/Shaheen3_genoa_results/2024-01-04-10-57-15--4267--570286
# 200 ./grid_perf/Shaheen3_genoa_results/2024-01-07-08-42-11--4991--583365
# 201 ./grid_perf/Shaheen3_genoa_results/2024-01-07-08-42-11--2756--581022
# 202 ./grid_perf/Shaheen3_genoa_results/2024-01-04-10-57-15--1409--555928
# 203 ./grid_perf/Shaheen3_genoa_results/2023-12-17-13-41-42--1186--389826
# 204 ./grid_perf/Shaheen3_genoa_results/2024-01-04-10-57-15--3899--558711
# 205 ./grid_perf/Shaheen3_genoa_results/2023-12-17-13-41-42--379--502996
# 206 ./grid_perf/Shaheen3_genoa_results/2024-01-09-09-06-47--3266--591692
# 207 ./grid_perf/Shaheen3_genoa_results/2024-01-04-10-57-15--3516--558326
# 208 ./grid_perf/Shaheen3_genoa_results/2024-01-09-09-06-47--4340--592792
# 209 ./grid_perf/Shaheen3_genoa_results/2024-01-07-08-42-11--2022--580236
# 210 ./grid_perf/Shaheen3_genoa_results/2024-01-09-09-06-47--5129--593584
# 211 ./grid_perf/Shaheen3_genoa_results/2024-01-09-09-06-47--791--589120
# 212 ./grid_perf/Shaheen3_genoa_results/2024-01-09-09-06-47--1227--589581
# 213 ./grid_perf/Shaheen3_genoa_results/2024-01-09-09-06-47--3075--591501
# 214 ./grid_perf/Shaheen3_genoa_results/2024-01-04-10-57-15--758--555193
# 215 ./grid_perf/Shaheen3_genoa_results/2024-01-07-08-42-11--937--579150
# 216 ./grid_perf/Shaheen3_genoa_results/2024-01-09-09-06-47--750--589079
# 217 ./grid_perf/Shaheen3_genoa_results/2024-01-04-10-57-15--717--555144
# 218 ./grid_perf/Shaheen3_genoa_results/2023-12-17-13-41-42--874--389307
# 219 ./grid_perf/Shaheen3_genoa_results/2023-12-17-13-41-42--1542--392604
# 220 ./grid_perf/Shaheen3_genoa_results/2024-01-04-10-57-15--471--554895
# 221 ./grid_perf/Shaheen3_genoa_results/2024-01-07-08-42-11--4745--583111
# 222 ./grid_perf/Shaheen3_genoa_results/2024-01-07-08-42-11--1377--579590
# 223 ./grid_perf/Shaheen3_genoa_results/2023-12-17-13-41-42--0--457788
# 224 ./grid_perf/Shaheen3_genoa_results/2024-01-09-09-06-47--953--589283
# 225 ./grid_perf/Shaheen3_genoa_results/2024-01-04-10-57-15--600--555027
# 226 ./grid_perf/Shaheen3_genoa_results/2023-12-17-13-41-42--376--503539
# 227 ./grid_perf/Shaheen3_genoa_results/2024-01-04-10-57-15--1049--555506
# 228 ./grid_perf/Shaheen3_genoa_results/2024-01-04-10-57-15--4936--571230
# 229 ./grid_perf/Shaheen3_genoa_results/2024-01-04-10-57-15--2820--557618
# 230 ./grid_perf/Shaheen3_genoa_results/2024-01-07-08-42-11--622--578834
# 231 ./grid_perf/Shaheen3_genoa_results/2023-12-17-13-41-42--323--503486
# 232 ./grid_perf/Shaheen3_genoa_results/2024-01-07-08-42-11--516--578728
# 233 ./grid_perf/Shaheen3_genoa_results/2024-01-04-10-57-15--1893--556428
# 234 ./grid_perf/Shaheen3_genoa_results/2024-01-09-09-06-47--5093--593547
# 235 ./grid_perf/Shaheen3_genoa_results/2024-01-04-10-57-15--5004--578081
# 236 ./grid_perf/Shaheen3_genoa_results/2024-01-09-09-06-47--2604--591030
# 237 ./grid_perf/Shaheen3_genoa_results/2024-01-07-08-42-11--2770--581041
# 238 ./grid_perf/Shaheen3_genoa_results/2024-01-04-10-57-15--2223--556818
# 239 ./grid_perf/Shaheen3_genoa_results/2023-12-17-13-41-42--254--503133
# 240 ./grid_perf/Shaheen3_genoa_results/2024-01-07-08-42-11--2871--581153
# 241 ./grid_perf/Shaheen3_genoa_results/2023-12-17-13-41-42--1649--392717
# 242 ./grid_perf/Shaheen3_genoa_results/2024-01-04-10-57-15--4778--571052
# 243 ./grid_perf/Shaheen3_genoa_results/2024-01-07-08-42-11--606--578818
# 244 ./grid_perf/Shaheen3_genoa_results/2024-01-04-10-57-15--1038--555495
# 245 ./grid_perf/Shaheen3_genoa_results/2024-01-04-10-57-15--3372--558181
# 246 ./grid_perf/Shaheen3_genoa_results/2024-01-04-10-57-15--2133--556728
# 247 ./grid_perf/Shaheen3_genoa_results/2024-01-09-09-06-47--833--589162
# 248 ./grid_perf/Shaheen3_genoa_results/2024-01-07-08-42-11--3224--581527
# 249 ./grid_perf/Shaheen3_genoa_results/2024-01-04-10-57-15--4413--570677
# 250 ./grid_perf/Shaheen3_genoa_results/2024-01-04-10-57-15--2038--556600
# 251 ./grid_perf/Shaheen3_genoa_results/2024-01-09-09-06-47--293--584037
# 252 ./grid_perf/Shaheen3_genoa_results/2024-01-09-09-06-47--5103--593558
# 253 ./grid_perf/Shaheen3_genoa_results/2024-01-09-09-06-47--573--584317
# 254 ./grid_perf/Shaheen3_genoa_results/2024-01-04-10-57-15--2765--557552
# 255 ./grid_perf/Shaheen3_genoa_results/2024-01-04-10-57-15--4481--570746
# 256 ./grid_perf/Shaheen3_genoa_results/2024-01-04-10-57-15--292--554716
# 257 ./grid_perf/Shaheen3_genoa_results/2024-01-07-08-42-11--4200--582509
# 258 ./grid_perf/Shaheen3_genoa_results/2024-01-04-10-57-15--3537--558347
# 259 ./grid_perf/Shaheen3_genoa_results/2024-01-04-10-57-15--3179--557987
# 260 ./grid_perf/Shaheen3_genoa_results/2024-01-09-09-06-47--880--589209
# 261 ./grid_perf/Shaheen3_genoa_results/2024-01-07-08-42-11--3527--581832
# 262 ./grid_perf/Shaheen3_genoa_results/2024-01-09-09-06-47--2415--590839
# 263 ./grid_perf/Shaheen3_genoa_results/2024-01-09-09-06-47--4347--592799
# 264 ./grid_perf/Shaheen3_genoa_results/2023-12-17-13-41-42--951--389534
# 265 ./grid_perf/Shaheen3_genoa_results/2024-01-09-09-06-47--
./grid_perf/Shaheen3_genoa_results/2024-01-07-08-42-11--3810--582116
# 17113 ./grid_perf/Shaheen3_genoa_results/2024-01-09-09-06-47--1225--589579
# 17114 ./grid_perf/Shaheen3_genoa_results/2024-01-07-08-42-11--2680--580941
# 17115 ./grid_perf/Shaheen3_genoa_results/2024-01-07-08-42-11--3299--581602
# 17116 ./grid_perf/Shaheen3_genoa_results/2024-01-04-10-57-15--4287--570309
# 17117 ./grid_perf/Shaheen3_genoa_results/2024-01-04-10-57-15--4960--571256
# 17118 ./grid_perf/Shaheen3_genoa_results/2023-12-17-13-41-42--1006--389610
# 17119 ./grid_perf/Shaheen3_genoa_results/2024-01-09-09-06-47--3538--591967
# 17120 ./grid_perf/Shaheen3_genoa_results/2024-01-09-09-06-47--3342--591768
# 17121 ./grid_perf/Shaheen3_genoa_results/2024-01-04-10-57-15--678--555105
# 17122 ./grid_perf/Shaheen3_genoa_results/2024-01-09-09-06-47--4588--593041
# 17123 ./grid_perf/Shaheen3_genoa_results/2024-01-09-09-06-47--1973--590390
# 17124 ./grid_perf/Shaheen3_genoa_results/2024-01-09-09-06-47--4410--592863
# 17125 ./grid_perf/Shaheen3_genoa_results/2024-01-09-09-06-47--752--589081
# 17126 ./grid_perf/Shaheen3_genoa_results/2024-01-07-08-42-11--5071--583449
# 17127 ./grid_perf/Shaheen3_genoa_results/2024-01-09-09-06-47--4196--592645
# 17128 ./grid_perf/Shaheen3_genoa_results/2024-01-07-08-42-11--2462--580693
# 17129 ./grid_perf/Shaheen3_genoa_results/2024-01-04-10-57-15--1813--556343
# 17130 ./grid_perf/Shaheen3_genoa_results/2024-01-09-09-06-47--4339--592791
# 17131 ./grid_perf/Shaheen3_genoa_results/2024-01-07-08-42-11--1914--580128
# 17132 ./grid_perf/Shaheen3_genoa_results/2024-01-04-10-57-15--2442--557199
# 17133 ./grid_perf/Shaheen3_genoa_results/2024-01-04-10-57-15--2593--557367
# 17134 ./grid_perf/Shaheen3_genoa_results/2023-12-17-13-41-42--70--503368
# 17135 ./grid_perf/Shaheen3_genoa_results/2024-01-07-08-42-11--4764--583133
# 17136 ./grid_perf/Shaheen3_genoa_results/2024-01-09-09-06-47--1201--589555
# 17137 ./grid_perf/Shaheen3_genoa_results/2024-01-09-09-06-47--2061--590485
# 17138 ./grid_perf/Shaheen3_genoa_results/2024-01-09-09-06-47--2159--590583
# 17139 ./grid_perf/Shaheen3_genoa_results/2024-01-04-10-57-15--186--554135
# 17140 ./grid_perf/Shaheen3_genoa_results/2024-01-07-08-42-11--1935--580149
# 17141 ./grid_perf/Shaheen3_genoa_results/2024-01-04-10-57-15--477--554901
# 17142 ./grid_perf/Shaheen3_genoa_results/2024-01-07-08-42-11--4315--582654
# 17143 ./grid_perf/Shaheen3_genoa_results/2024-01-04-10-57-15--3370--558179
# 17144 ./grid_perf/Shaheen3_genoa_results/2024-01-09-09-06-47--2954--591380
# 17145 ./grid_perf/Shaheen3_genoa_results/2024-01-09-09-06-47--1383--589737
# 17146 ./grid_perf/Shaheen3_genoa_results/2024-01-09-09-06-47--1337--589691
# 17147 ./grid_perf/Shaheen3_genoa_results/2024-01-07-08-42-11--1404--579617
# 17148 ./grid_perf/Shaheen3_genoa_results/2024-01-04-10-57-15--4011--559281
# 17149 ./grid_perf/Shaheen3_genoa_results/2024-01-04-10-57-15--672--555099
# 17150 ./grid_perf/Shaheen3_genoa_results/2024-01-09-09-06-47--4538--592991
# 17151 ./grid_perf/Shaheen3_genoa_results/2024-01-04-10-57-15--195--554269
# 17152 ./grid_perf/Shaheen3_genoa_results/2024-01-09-09-06-47--2177--590601
# 17153 ./grid_perf/Shaheen3_genoa_results/2024-01-07-08-42-11--2350--580570
# 17154 ./grid_perf/Shaheen3_genoa_results/2024-01-07-08-42-11--3745--582051
# 17155 ./grid_perf/Shaheen3_genoa_results/2024-01-04-10-57-15--1223--555696
# 17156 ./grid_perf/Shaheen3_genoa_results/2024-01-09-09-06-47--3337--591763
# 17157 ./grid_perf/Shaheen3_genoa_results/2024-01-04-10-57-15--3007--557813
# 17158 ./grid_perf/Shaheen3_genoa_results/2024-01-04-10-57-15--4196--564918
# 17159 ./grid_perf/Shaheen3_genoa_results/2024-01-04-10-57-15--338--554762
# 17160 ./grid_perf/Shaheen3_genoa_results/2024-01-09-09-06-47--4957--593411
# 17161 ./grid_perf/Shaheen3_genoa_results/2024-01-04-10-57-15--1680--556201
# 17162 ./grid_perf/Shaheen3_genoa_results/2024-01-07-08-42-11--2723--580984
# 17163 ./grid_perf/Shaheen3_genoa_results/2024-01-04-10-57-15--1991--556545
# 17164 ./grid_perf/Shaheen3_genoa_results/2024-01-07-08-42-11--1153--579366
# 17165 ./grid_perf/Shaheen3_genoa_results/2024-01-04-10-57-15--3205--558013
# 17166 ./grid_perf/Shaheen3_genoa_results/2024-01-09-09-06-47--2579--591005
# 17167 ./grid_perf/Shaheen3_genoa_results/2024-01-07-08-42-11--776--578988
# 17168 ./grid_perf/Shaheen3_genoa_results/2024-01-07-08-42-11--5050--583428
# 17169 ./grid_perf/Shaheen3_genoa_results/2024-01-04-10-57-15--2101--556690
# 17170 ./grid_perf/Shaheen3_genoa_results/2023-12-17-13-41-42--1240--389890
# 17171 ./grid_perf/Shaheen3_genoa_results/2024-01-07-08-42-11--386--578598
# Index(['filenames', 'method', 'grids', 'giga_point_s', 'cores', 'sim_info',
#        'times', 'giga_flop_s', 'point_updates', 'Flops'],
#       dtype='object')
# ['2048 x 2048 x 512' '2048 x 2048 x 1024' '1024 x 1024 x 512'
#  '2048 x 2048 x 2048' '512 x 512 x 512']
# ['tb_order2' 'tb_order2_abc' 'tb' 'tb_abc' 'sb_abc' 'sb_order2_abc'
#  'sb_order2' 'sb']
# results will be plotted for grids= ['512 x 512 x 512', '1024 x 1024 x 512', '2048 x 2048 x 512']
# [192.  96.  48.   1.]
# ['tb_order2' 'tb_order2_abc' 'tb' 'tb_abc' 'sb_abc' 'sb_order2_abc'
#  'sb_order2' 'sb']
# Index(['filenames', 'method', 'grids', 'giga_point_s', 'cores', 'sim_info',
#        'times', 'giga_flop_s', 'point_updates', 'Flops'],
#       dtype='object')
# ['512 x 512 x 512', 29.9592, 31.85, 29.821, 31.0635]
# ['1024 x 1024 x 512', 22.7049, 62.6628, 20.2959, 61.1967]
# ['2048 x 2048 x 512', 22.8338, 82.4036, 22.7432, 78.5751]

# %%
####################### Plot bar charts #######################
def plot_perf(data_list,save_paths,title='',metric='gstencils',gflops_limit=3300,gstencils_limit=100):
    print('metric=',metric)
    barWidth = 0.25
    # fig, ax = plt.subplots(1,len(data_list),figsize=(7.5*len(data_list),5))
    font = {'size': 17};    
    plt.rc('font', **font)
    plt.rcParams["font.weight"]="bold"
    # fig, ax = plt.subplots(1,len(data_list),figsize=(22*len(data_list),2.0))  # first variant
    fig, ax = plt.subplots(1,len(data_list),figsize=(7.5*len(data_list),2.0))  # second variant

    # Set position of bar on X axis 
    br1 = np.arange(2)
    br2 = [x + barWidth for x in br1]
    print(br1)
    print(br2)
    for (counter,data) in enumerate(data_list):
        grid_name=data[0];
        if grid_name=='512 x 512 x 512':        grid_name='512*512*512';
        if grid_name=='1024 x 1024 x 512':      grid_name='1024*1024*512';
        if grid_name=='2048 x 2048 x 512':      grid_name='2048*2048*512';
        SB=[data[1],data[3]]; 
        TB=[data[2],data[4]];
        # Make the plot
        if len(data_list)==1:
            AX=ax
        else:
            AX=ax[counter]
        
        bars=AX.bar(br1, SB, color ='b', width = barWidth,edgecolor ='grey', label ='SB')
        for bar in bars:
            yval = bar.get_height()
            if metric=='gflops':
                plot_val=int(yval)
            else:
                plot_val=round(yval,1)
            AX.text(bar.get_x()-0.04,yval+yval*0.02,plot_val,fontsize=18,fontweight='bold')   # bold, normal
        
        bars=AX.bar(br2, TB, color ='r', width = barWidth,edgecolor ='grey', label ='MWD')
        for bar in bars:
            yval = bar.get_height()
            if metric=='gflops':
                plot_val=int(yval)
            else:
                plot_val=round(yval,1)
            AX.text(bar.get_x()+0.04,yval+yval*0.02,plot_val,fontsize=18,fontweight='bold')

        AX.set_xticks([0.125,1.125],['Stencil','Stencil+ABCs'], fontweight ='bold', fontsize = 18)
        AX.tick_params(axis='y', labelsize=17)

        if metric=='gflops':
            AX.set_ylabel('GFlop/s', fontweight ='bold', fontsize = 18)
            AX.set_ylim(bottom=0,top=gflops_limit)
        else:
            AX.set_ylabel('GStencils/s', fontweight ='bold', fontsize = 18)
            AX.set_ylim(bottom=0,top=gstencils_limit)

        AX.legend(loc='upper center')
        AX.set_title('Grid size:'+grid_name,fontweight='bold')

    my_suptitle=fig.suptitle('',fontsize=18,y=0,weight='bold')
    plt.show()
    fig.savefig(save_paths[0],bbox_inches='tight',bbox_extra_artists=[my_suptitle])
    fig.savefig(save_paths[1],bbox_inches='tight',bbox_extra_artists=[my_suptitle])
    return None

save_paths=['../performances/sh3_1st_grids_gstencils.pdf',
            '../performances/sh3_1st_grids_gstencils.png']
plot_perf(data_list_1st_grid,save_paths,title='',metric='gstencils',gstencils_limit=150)

save_paths=['../performances/sh3_2nd_grids_gstencils.pdf',
            '../performances/sh3_2nd_grids_gstencils.png']
plot_perf(data_list_2nd_grid,save_paths,title='',metric='gstencils',gstencils_limit=150)
################ plot scalability plot ################################
print(data['cores'].unique())
print(data.columns)
# Out:
# metric= gstencils
# [0 1]
# [0.25, 1.25]
# metric= gstencils
# [0 1]
# [0.25, 1.25]
# [192.  96.  48.   1.]
# Index(['filenames', 'method', 'grids', 'giga_point_s', 'cores', 'sim_info',
#        'times', 'giga_flop_s', 'point_updates', 'Flops'],
#       dtype='object')
